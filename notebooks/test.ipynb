# %%
# !pip install pydantic
# Out:
# ...
#      ------------------------------------- 463.6/463.6 kB 14.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.0/2.0 MB 21.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pydantic import BaseModel

class Car(BaseModel) :
    id: int
    maker: str
    model: str
    year: int

# %%
car = Car(id=1, maker="Tesla", model="Model X", year=2024)

# %%
# str(car)
car.model_fields
# Out:
# C:\Users\ddasi\AppData\Local\Temp\ipykernel_38952\410175886.py:2: PydanticDeprecatedSince211: Accessing the 'model_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   car.model_fields
# {'id': FieldInfo(annotation=int, required=True),
#  'maker': FieldInfo(annotation=str, required=True),
#  'model': FieldInfo(annotation=str, required=True),
#  'year': FieldInfo(annotation=int, required=True)}
